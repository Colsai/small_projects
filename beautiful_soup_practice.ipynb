# %% [markdown]
# <a href="https://colab.research.google.com/github/Colsai/Small-Assignments/blob/main/beautiful_soup_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Packages
import numpy as np
import random
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
page = requests.get('https://www.thecustommovement.com/custom/wcXmcXCj/stan-smith-chinese-dragon')
website = page.content

# %%
#https://stackoverflow.com/questions/54725399/how-to-take-specific-elements-on-multiple-lists-on-beautifulsoup

soup = BeautifulSoup(website, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <link href="https://media.thecustommovement.com" rel="preconnect"/>
#   <link href="https://media.thecustommovement.com" rel="dns-prefetch"/>
#   <link as="font" crossorigin="anonymous" href="/static/assets/GT-Sectra-Book.ttf" rel="preload" type="font/ttf"/>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-G445DBPE98">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#           function gtag(){dataLayer.push(arguments);}
#           gtag('js', new Date());
#
#           gtag('config', 'G-G445DBPE98');
#   </script>
#   <script>
# ...

# %%
#Title
soup.title
# Out:
# <title>Stan Smith 'Chinese Dragon' | THE CUSTOM MOVEMENT</title>

# %%
shoe_name = soup.title.string

# %%
soup.find_all('meta')
# Out:
# [<meta charset="utf-8"/>,
#  <meta content="width=device-width, initial-scale=1" name="viewport"/>,
#  <meta content="
#  This timeless Adidas Stan Smith Low Top sneaker has a hand-painted'Chinese Dragon' design on the outside. The shoe is made of leather and combines a sporty and elegant silhouette. It is refined by hand with the utmost care and quality by Born Originals® in Germany. The shoes are delivered in an exclusive Born Originals® sneaker box with certificate of authenticity.
#  Every pair is hand-painted to order. This is a customization SERVICE. This cost includes a sourcing fee, for the base pair Air Force in size ordered. Please note the processing time, as this sneaker is finished to order and is not delivered immediately. The product is made for casual wearing and should not be scratched. Care and cleaning instructions can be found in our FAQ. The sale of this product is final and excluded from refunds and exchanges.
#
#  " name="description"/>,
#  <meta content="
# ...

# %%
print(soup.get_text())
# Out:
#           window.dataLayer = window.dataLayer || [];
#           function gtag(){dataLayer.push(arguments);}
#           gtag('js', new Date());
#
#           gtag('config', 'G-G445DBPE98');
#
#           window.heap=window.heap||[],heap.load=function(e,t){window.heap.appid=e,window.heap.config=t=t||{};var r=t.forceSSL||"https:"===document.location.protocol,a=document.createElement("script");a.type="text/javascript",a.async=!0,a.src=(r?"https:":"http:")+"//cdn.heapanalytics.com/js/heap-"+e+".js";var n=document.getElementsByTagName("script")[0];n.parentNode.insertBefore(a,n);for(var o=function(e){return function(){heap.push([e].concat(Array.prototype.slice.call(arguments,0)))}},p=["addEventProperties","addUserProperties","clearEventProperties","identify","removeEventProperty","setEventProperties","track","unsetEventProperty"],c=0;c<p.length;c++)heap[p[c]]=o(p[c])};
#           heap.load(4009200213);
#
#           !function(e){if(!window.pintrk){window.pintrk = function () {
# ...
